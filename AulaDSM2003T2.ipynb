# %% [markdown]
# <a href="https://colab.research.google.com/github/LMVieira2/Machine-Learning-Fatec-Matao/blob/main/AulaDSM2003T2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação das Bibliotecas

# %% [markdown]
# pandas [https://pandas.pydata.org/docs/getting_started/index.html#getting-started]
#
# numpy [https://numpy.org/doc/2.2/user/absolute_beginners.html]
#
# seaborn [https://seaborn.pydata.org/]
#
# MatPlotLib [https://matplotlib.org/cheatsheets/]
#
# Express [https://plotly.com/python/plotly-express/]

# %%
# !pip install plotly --upgrade
# !pip install squarify --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly) (1.30.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: squarify in /usr/local/lib/python3.11/dist-packages (0.4.4)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import requests

# %% [markdown]
# # Carregamento do Dataset

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&outputsize=full&apikey=NES1FN2QJITLR295'

r = requests.get(url)
data = r.json()

time_series = data["Time Series (Daily)"]

base_acoes = pd.DataFrame.from_dict(time_series, orient='index')

base_acoes.columns  = ['Abertura', 'Alta', 'Baixa', 'Fechamento', 'Volume']
base_acoes = base_acoes.astype(float)
base_acoes.index = pd.to_datetime(base_acoes.index)
base_acoes = base_acoes.sort_index()

# %%
base_acoes.describe()
# Out:
#           Abertura         Alta        Baixa   Fechamento        Volume
# count  6384.000000  6384.000000  6384.000000  6384.000000  6.384000e+03
# mean    133.267925   134.476297   132.136765   133.334645  5.880132e+06
# std      38.245296    38.370096    38.121722    38.273895  3.292569e+06
# min      54.650000    56.700000    54.010000    55.070000  1.027500e+06
# 25%     102.337500   103.842500   100.840000   102.310000  3.725534e+06
# 50%     129.565000   130.590000   128.480000   129.570000  5.032773e+06
# 75%     159.000000   160.245000   158.007500   159.050000  7.080328e+06
# max     265.710000   266.450000   262.150000   264.740000  4.120730e+07

# %%
base_acoes["Tendencia"] = base_acoes["Fechamento"].diff().shift(-1)
base_acoes["Tendencia"] = base_acoes["Tendencia"].apply(lambda x: "alta" if x > 0 else "baixa")

base_acoes
# Out:
#             Abertura      Alta   Baixa  Fechamento      Volume Tendencia
# 1999-11-01    98.500   98.8100   96.37       96.75   9551800.0     baixa
# 1999-11-02    96.750   96.8100   93.69       94.81  11105400.0     baixa
# 1999-11-03    95.870   95.9400   93.50       94.37  10369100.0     baixa
# 1999-11-04    94.440   94.4400   90.00       91.56  16697600.0     baixa
# 1999-11-05    92.750   92.9400   90.19       90.25  13737600.0      alta
# ...              ...       ...     ...         ...         ...       ...
# 2025-03-13   248.800  249.2700  243.04      245.80   3862416.0      alta
# 2025-03-14   242.745  248.9499  241.68      248.35   4045284.0      alta
# 2025-03-17   249.250  254.6300  249.00      252.97   3234149.0     baixa
# 2025-03-18   252.510  252.5700  245.12      246.95   4172239.0      alta
# 2025-03-19   248.330  253.6600  246.64      252.29   3853598.0     baixa
#
# [6384 rows x 6 columns]
